# %% [markdown]
# # Welcome to My Web Mining Pages
#
#
# Ini adalah halaman matakuliah Penambangan Web saya yang memuat informasi seputar Penambangan Web. Dengan halaman ini, kita bisa mempelajari berbagai ilmu tentang Sains Data. Semoga para pengunjung mendapat ilmu yang bermanfaat !
#
#
# ---
#
# ## Biodata
#
#
# **Nama Lengkap** : **Muhammad Ilham Adila Almafaz**
# **NIM** : **230411100113**
# **Program Studi** : Teknik Informatika
# **Fakultas** : Teknik
# **Universitas** : Universitas Trunojoyo Madura
# **Email Mahasiswa** : 230411100113@student.trunojoyo.ac.id
# **Mata Kuliah** : Penambangan & Pencarian Web (PPW)
#
# ---
#
# ## 🎯 Tentang Praktikum PPW
# Mata kuliah **Penambangan & Pencarian Web** mencakup eksplorasi pengumpulan data dari internet (*web crawling / scraping*), pembersihan dan praproses teks (*preprocessing*), ekstraksi informasi berbasis NLP (*Natural Language Processing*), pemodelan dokumen (*TF-IDF, Topic Modeling*), hingga analisis perayapan dan temu balik informasi (*Information Retrieval*).
#
# :::{note}
# Dokumentasi praktikum disajikan secara terstruktur dan interaktif. Anda dapat meninjau kode program dan penjelasannya pada menu navigasi tugas di bawah.
# :::

# %% [markdown]
# ## 📂 Daftar Tugas Praktikum
#
# 1. [**Tugas 1: Crawling & Ekstraksi Konten Berita Olahraga dengan Trafilatura**](WebMining_Tugas1.ipynb)
#    - Mengambil URL berita dari Detik Sport kategori raket (/raket/d-).
#    - Menyaring dan menghilangkan duplikasi tautan artikel.
#    - Mengunduh dan mengekstrak teks isi berita, judul, serta metadata menggunakan pustaka 	rafilatura.
#    - Mengolah dan menyusun data ke dalam tabel pandas.DataFrame.

# %%
# Menampilkan Ringkasan Data Profil Mahasiswa
import pandas as pd

biodata = {
    'Informasi': [
        'Nama Lengkap',
        'NPM',
        'Program Studi',
        'Email Mahasiswa',
        'Mata Kuliah',
        'Tugas 1'
    ],
    'Keterangan': [
        'Muhammad Ilham Adila Almafaz',
        '23-113 (230411100113)',
        'Teknik Informatika - UTM',
        '230411100113@student.trunojoyo.ac.id',
        'Penambangan & Pencarian Web',
        'Web Crawling Detik Sport dengan Trafilatura'
    ]
}

df = pd.DataFrame(biodata)
df

# %% [markdown]
# ---
# ### 📬 Kontak
# - **Email**: [230411100113@student.trunojoyo.ac.id](mailto:230411100113@student.trunojoyo.ac.id)
# - **Kampus**: Universitas Trunojoyo Madura (UTM)
